# %%
import tkinter as tk
from tkinter import filedialog
import numpy as np
import os
from brukeropusreader import read_file

def calculate_snr(signal, noise):
    """
    Berechnet das Signal-to-Noise Ratio (SNR).
    :param signal: Numpy Array des Signals.
    :param noise: Numpy Array des Rauschens.
    :return: SNR-Wert.
    """
    signal_power = np.mean(signal ** 2)
    noise_power = np.mean(noise ** 2)
    snr = 10 * np.log10(signal_power / noise_power)
    return snr

def process_files():
    root = tk.Tk()
    root.withdraw()  # Verstecke das Hauptfenster
    # Öffne den Dateidialog und hole die Dateipfade
    file_paths = filedialog.askopenfilenames()
    for file_path in file_paths:
        if file_path:
            # Lese die OPUS-Datei
            opus_data = read_file(file_path)
            file_name = os.path.basename(file_path)
            absorbance = opus_data['AB']

            start_wn = opus_data['AB Data Parameter']['FXV']
            end_wn = opus_data['AB Data Parameter']['LXV']
            num_points = opus_data['AB Data Parameter']['NPT']
            num_points = len(absorbance)
            wavenumbers = np.linspace(start_wn, end_wn, num_points)
            assert len(wavenumbers) == len(absorbance), "Wavenumbers and absorbance arrays must be the same length."

            # Hier fügen wir eine einfache Rauschberechnung hinzu, indem wir einen Teil des Spektrums als Rauschen betrachten
            # Dies ist nur ein Beispiel und sollte an Ihre spezifischen Daten angepasst werden
            noise_region = absorbance[-100:]  # Nehmen wir die letzten 50 Punkte als Rauschen
            snr_value = calculate_snr(absorbance, noise_region)
            print(f"SNR for {file_name}: {snr_value} dB")

process_files()
# Out:
# SNR for 15012024 OE 1.0000: 2.3577188904001165 dB
# SNR for 15012024 OE 1.0001: 2.8574152906637744 dB
# SNR for 15012024 OE 1.0002: 1.9195934533626202 dB
# SNR for 15012024 OE 1.0003: 2.0130357007209247 dB
# SNR for 15012024 OE 1.0004: 2.362558033253524 dB
# SNR for 15012024 OE 2.0005: 2.5790728611636964 dB
# SNR for 15012024 OE 2.0006: 2.416160950181967 dB
# SNR for 15012024 OE 2.0007: 2.2407298515703307 dB
# SNR for 15012024 OE 2.0008: 2.097321140124212 dB
# SNR for 15012024 OE 2.0009: 2.4050568541182193 dB
# SNR for 15012024 OE 3.0010: 2.554137715383717 dB
# SNR for 15012024 OE 3.0011: 2.734836546335533 dB
# SNR for 15012024 OE 3.0012: 2.683059960716088 dB
# SNR for 15012024 OE 3.0013: 2.2405923086583197 dB
# SNR for 15012024 OE 3.0014: 2.2412449806372994 dB
# SNR for 15012024 OE 4.0000: 2.1011520964786126 dB
# SNR for 15012024 OE 4.0001: 1.7558473039729796 dB
# SNR for 15012024 OE 4.0002: 2.5811509105446238 dB
# SNR for 15012024 OE 4.0003: 2.0774962179646366 dB
# SNR for 15012024 OE 4.0004: 2.6045142723477483 dB
# SNR for 15012024 OE 5.0000: 2.3350951513127325 dB
# SNR for 15012024 OE 5.0001: 2.4360077891520144 dB
# SNR for 15012024 OE 5.0002: 2.2649448160177164 dB
# SNR for 15012024 OE 5.0003: 2.0310533520848497 dB
# SNR for 15012024 OE 5.0004: 2.239788701580612 dB
# SNR for 15012024 RE 1.0000: 1.8294881291042127 dB
# SNR for 15012024 RE 1.0001: 2.497878644025661 dB
# SNR for 15012024 RE 1.0002: 2.14871887079698 dB
# SNR for 15012024 RE 1.0003: 1.7837292605988018 dB
# SNR for 15012024 RE 1.0004: 1.8989113349534716 dB
# SNR for 15012024l RE 2.0000: 1.9705549244013356 dB
# SNR for 15012024l RE 2.0001: 2.3823984643067746 dB
# SNR for 15012024l RE 2.0002: 2.1966306267585667 dB
# SNR for 15012024l RE 2.0003: 1.9547838558073325 dB
# SNR for 15012024l RE 2.0004: 2.2539486625632037 dB
# SNR for 15012024l RE 3.0005: 2.284813057281237 dB
# SNR for 15012024l RE 3.0006: 2.566422866925147 dB
# SNR for 15012024l RE 3.0007: 2.558342540360943 dB
# SNR for 15012024l RE 3.0008: 2.8177592078638836 dB
# SNR for 15012024l RE 3.0009: 2.4207533436084274 dB
# SNR for 15012024l RE 4.0010: 2.3120390142915315 dB
# SNR for 15012024l RE 4.0011: 2.379942067809586 dB
# SNR for 15012024l RE 4.0012: 2.440824721758714 dB
# SNR for 15012024l RE 4.0013: 2.592017226976497 dB
# SNR for 15012024l RE 4.0014: 2.1082362919467306 dB
# SNR for 15012024l RE 5.0015: 2.421660153021322 dB
# SNR for 15012024l RE 5.0016: 2.752162117783168 dB
# SNR for 15012024l RE 5.0017: 2.421797784493916 dB
# SNR for 15012024l RE 5.0018: 2.330702927954568 dB
# SNR for 15012024l RE 5.0019: 2.6289767987653723 dB
# SNR for 20240304 OE 1.0000: 2.0495581867239343 dB
# SNR for 20240304 OE 1.0001: 2.5472223987032554 dB
# SNR for 20240304 OE 1.0002: 2.2761481450548406 dB
# SNR for 20240304 OE 1.0003: 1.796830270529918 dB
# SNR for 20240304 OE 1.0004: 1.8291494555077994 dB
# SNR for 20240304 OE 2.0000: 1.350878938696515 dB
# SNR for 20240304 OE 2.0001: 2.0159430289180187 dB
# SNR for 20240304 OE 2.0002: 2.0333556380769306 dB
# SNR for 20240304 OE 2.0003: 2.4196797422178777 dB
# SNR for 20240304 OE 2.0004: 2.057093757422538 dB
# SNR for 20240304 OE 3.0000: 2.0680314385303773 dB
# SNR for 20240304 OE 3.0001: 2.028597030582598 dB
# SNR for 20240304 OE 3.0002: 1.995749983273659 dB
# SNR for 20240304 OE 3.0003: 1.6970828343684652 dB
# SNR for 20240304 OE 3.0004: 1.6135840354626796 dB
# SNR for 20240304 OE 4.0000: 2.7712849648488342 dB
# SNR for 20240304 OE 4.0001: 2.891709930531148 dB
# SNR for 20240304 OE 4.0002: 2.77662491028827 dB
# SNR for 20240304 OE 4.0003: 3.139511872880078 dB
# SNR for 20240304 OE 4.0004: 3.4174959409652974 dB
# SNR for 20240304 OE 4.0005: 2.007724516021056 dB
# SNR for 20240304 OE 4.0006: 1.9412771808551095 dB
# SNR for 20240304 OE 4.0007: 2.0185309435649255 dB
# SNR for 20240304 OE 4.0008: 1.670787920536073 dB
# SNR for 20240304 OE 4.0009: 2.055125416037951 dB
# SNR for 20240304 OE 5.0000: 2.020629601314296 dB
# SNR for 20240304 OE 5.0001: 1.5700998205648955 dB
# SNR for 20240304 OE 5.0002: 1.592553876082234 dB
# SNR for 20240304 OE 5.0003: 2.0158119023184797 dB
# SNR for 20240304 OE 5.0004: 1.783212432385255 dB
# SNR for 20240304 OE 5.0005: 2.369475658484825 dB
# SNR for 20240304 OE 5.0006: 2.3428982845358104 dB
# SNR for 20240304 OE 5.0007: 2.616241838115252 dB
# SNR for 20240304 OE 5.0008: 2.0981445921780963 dB
# SNR for 20240304 OE 5.0009: 2.6157804891362675 dB
# SNR for 20240304 RE 1.0000: 1.6094648905944997 dB
# SNR for 20240304 RE 1.0001: 2.2954396344579098 dB
# SNR for 20240304 RE 1.0002: 1.753196476210078 dB
# SNR for 20240304 RE 1.0003: 2.105437071358457 dB
# SNR for 20240304 RE 1.0004: 2.0417874296820413 dB
# SNR for 20240304 RE 2.0000: 1.780213332403172 dB
# SNR for 20240304 RE 2.0001: 1.9892860464816995 dB
# SNR for 20240304 RE 2.0002: 1.8358080070871283 dB
# SNR for 20240304 RE 2.0003: 1.8340786688017947 dB
# SNR for 20240304 RE 2.0004: 1.9055074967700203 dB
# SNR for 20240304 RE 3.0000: 1.692140887310018 dB
# SNR for 20240304 RE 3.0001: 1.6320520095017756 dB
# SNR for 20240304 RE 3.0002: 1.7746907130402696 dB
# SNR for 20240304 RE 3.0003: 1.6697592580734908 dB
# SNR for 20240304 RE 3.0004: 1.9468616332647084 dB
# SNR for 20240304 RE 4.0000: 2.275956017262111 dB
# SNR for 20240304 RE 4.0001: 2.350877077963843 dB
# SNR for 20240304 RE 4.0002: 1.8263792803363452 dB
# SNR for 20240304 RE 4.0003: 1.7913396638882393 dB
# SNR for 20240304 RE 4.0004: 1.987681754831863 dB
# SNR for 20240304 RE 5.0000: 1.942522688590571 dB
# SNR for 20240304 RE 5.0001: 2.853025346599166 dB
# SNR for 20240304 RE 5.0002: 2.514744779137149 dB
# SNR for 20240304 RE 5.0003: 2.732259312674394 dB
# SNR for 20240304 RE 5.0004: 2.968381713151345 dB
# SNR for 20240311 OE 1.0000: 2.326267665153465 dB
# SNR for 20240311 OE 1.0001: 2.5679379805797744 dB
# SNR for 20240311 OE 1.0002: 1.9269143735300223 dB
# SNR for 20240311 OE 1.0003: 1.9417133458830254 dB
# SNR for 20240311 OE 1.0004: 2.1095297116675007 dB
# SNR for 20240311 OE 2.0000: 2.132320708654588 dB
# SNR for 20240311 OE 2.0001: 2.0463576313740535 dB
# SNR for 20240311 OE 2.0002: 2.1247307924076764 dB
# SNR for 20240311 OE 2.0003: 1.9641005108919996 dB
# SNR for 20240311 OE 2.0004: 2.631782270982523 dB
# SNR for 20240311 OE 3.0000: 1.6648100393660348 dB
# SNR for 20240311 OE 3.0001: 1.4584071010123147 dB
# SNR for 20240311 OE 3.0002: 1.949477462359703 dB
# SNR for 20240311 OE 3.0003: 1.980864525245796 dB
# SNR for 20240311 OE 3.0004: 1.647316732412737 dB
# SNR for 20240311 OE 3.0005: 2.158049780288886 dB
# SNR for 20240311 OE 3.0006: 2.4312083595555576 dB
# SNR for 20240311 OE 3.0007: 2.2839533046052836 dB
# SNR for 20240311 OE 3.0008: 2.070203557702409 dB
# SNR for 20240311 OE 3.0009: 2.652608602250059 dB
# SNR for 20240311 OE 5.0000: 2.04948817313551 dB
# SNR for 20240311 OE 5.0001: 2.2176077313093505 dB
# SNR for 20240311 OE 5.0002: 1.8904123899595984 dB
# SNR for 20240311 OE 5.0003: 1.9987274939001451 dB
# SNR for 20240311 OE 5.0004: 1.9263794590941885 dB
# SNR for 20240311 RE 1.0000: 2.187425919084285 dB
# SNR for 20240311 RE 1.0001: 2.307203121319507 dB
# SNR for 20240311 RE 1.0002: 2.1687038790483983 dB
# SNR for 20240311 RE 1.0003: 1.6274351680885135 dB
# SNR for 20240311 RE 1.0004: 2.4005702140091865 dB
# SNR for 20240311 RE 1.0005: 2.1102220210780525 dB
# SNR for 20240311 RE 1.0006: 2.1047201233155253 dB
# SNR for 20240311 RE 1.0007: 2.242924652295069 dB
# SNR for 20240311 RE 1.0008: 1.9025120109966898 dB
# SNR for 20240311 RE 1.0009: 2.0844400912366083 dB
# SNR for 20240311 RE 2.0000: 1.900372032386065 dB
# SNR for 20240311 RE 2.0001: 1.4766563537158925 dB
# SNR for 20240311 RE 2.0002: 2.150638719669051 dB
# SNR for 20240311 RE 2.0003: 2.3774997530269646 dB
# SNR for 20240311 RE 2.0004: 2.1628225250920545 dB
# SNR for 20240311 RE 3.0000: 1.8322568431021227 dB
# SNR for 20240311 RE 3.0001: 1.965881651543363 dB
# SNR for 20240311 RE 3.0002: 2.326113923986242 dB
# SNR for 20240311 RE 3.0003: 2.1200373755593303 dB
# SNR for 20240311 RE 3.0004: 1.9466507676599678 dB
# SNR for 20240311 RE 4.0000: 1.9257068001783688 dB
# SNR for 20240311 RE 4.0001: 2.336180491875906 dB
# SNR for 20240311 RE 4.0002: 2.3177797608831954 dB
# SNR for 20240311 RE 4.0003: 2.633590114895245 dB
# SNR for 20240311 RE 4.0004: 2.051887441417394 dB
# SNR for 20240311 RE 5.0000: 1.9647593048465324 dB
# SNR for 20240311 RE 5.0001: 1.8542307816904775 dB
# SNR for 20240311 RE 5.0002: 1.9780921366546436 dB
# SNR for 20240311 RE 5.0003: 1.9629302134540525 dB
# SNR for 20240311 RE 5.0004: 1.3747428663623051 dB
# SNR for 20240318 OE A1.0000: 2.0865124924892213 dB
# SNR for 20240318 OE A1.0001: 1.7514897674259022 dB
# SNR for 20240318 OE A1.0002: 1.6803751672391434 dB
# SNR for 20240318 OE A1.0003: 1.6454416428081902 dB
# SNR for 20240318 OE A1.0004: 1.6151226694257774 dB
# SNR for 20240318 OE A2.0000: 2.166264177564176 dB
# SNR for 20240318 OE A2.0001: 1.6656872782850667 dB
# SNR for 20240318 OE A2.0002: 2.028801068019723 dB
# SNR for 20240318 OE A2.0003: 2.132228066601284 dB
# SNR for 20240318 OE A2.0004: 1.9446214618161553 dB
# SNR for 20240318 OE A3.0000: 1.7732570238326248 dB
# SNR for 20240318 OE A3.0001: 1.93936775528784 dB
# SNR for 20240318 OE A3.0002: 2.0470184283466004 dB
# SNR for 20240318 OE A3.0003: 1.5288009986160034 dB
# SNR for 20240318 OE A3.0004: 1.8974042158362716 dB
# SNR for 20240318 OE A4.0000: 1.5082311799076884 dB
# SNR for 20240318 OE A4.0001: 1.4904590732863376 dB
# SNR for 20240318 OE A4.0002: 1.71870306933016 dB
# SNR for 20240318 OE A4.0003: 1.649797897508787 dB
# SNR for 20240318 OE A4.0004: 1.8840785262013133 dB
# SNR for 20240318 OE A5.0000: 1.5245156297145441 dB
# SNR for 20240318 OE A5.0001: 1.8065812100490233 dB
# SNR for 20240318 OE A5.0002: 1.768803465413542 dB
# SNR for 20240318 OE A5.0003: 2.173777800949461 dB
# SNR for 20240318 OE A5.0004: 1.7419936559384095 dB
# SNR for 20240318 RE B1.0000: 1.8075299439430361 dB
# SNR for 20240318 RE B1.0001: 1.9149294599554378 dB
# SNR for 20240318 RE B1.0002: 1.2016128679306144 dB
# SNR for 20240318 RE B1.0003: 1.3958065360913454 dB
# SNR for 20240318 RE B1.0004: 1.7424533438896046 dB
# SNR for 20240318 RE B2.0000: 1.7801329471133038 dB
# SNR for 20240318 RE B2.0001: 1.7150062990423511 dB
# SNR for 20240318 RE B2.0002: 1.9960126901012223 dB
# SNR for 20240318 RE B2.0003: 2.0222114345776845 dB
# SNR for 20240318 RE B2.0004: 1.561689322117754 dB
# SNR for 20240318 RE B3.0000: 1.4888497052579917 dB
# SNR for 20240318 RE B3.0001: 1.6916954038598206 dB
# SNR for 20240318 RE B3.0002: 1.9701326993877524 dB
# SNR for 20240318 RE B3.0003: 1.6897205717517403 dB
# SNR for 20240318 RE B3.0004: 1.8731453966415754 dB
# SNR for 20240318 RE B4.0000: 1.8055770460320604 dB
# SNR for 20240318 RE B4.0001: 1.3368716104070524 dB
# SNR for 20240318 RE B4.0002: 1.9904213489008027 dB
# SNR for 20240318 RE B4.0003: 1.8783265326729413 dB
# SNR for 20240318 RE B4.0004: 1.6620807242523628 dB
# SNR for 20240318 RE B5.0000: 2.262485780439448 dB
# SNR for 20240318 RE B5.0001: 1.8833756300628448 dB
# SNR for 20240318 RE B5.0002: 1.7345245586243454 dB
# SNR for 20240318 RE B5.0003: 1.5508030062210794 dB
# SNR for 20240318 RE B5.0004: 1.8903765356059707 dB
