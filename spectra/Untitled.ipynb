# %%
import tkinter as tk
from tkinter import filedialog
import numpy as np
import os
from brukeropusreader import read_file

def z_score_normalization(data):
    mean = np.mean(data)
    std = np.std(data)
    normalized_data = (data - mean) / std
    return normalized_data

def open_files_and_save_normalized(file_paths):
    # Create the directory if it doesn't exist
    output_directory = "normalized_spectra"
    if not os.path.exists(output_directory):
        os.makedirs(output_directory)
    
    for file_path in file_paths:
        # Reading the OPUS file
        opus_data = read_file(file_path)
        file_name = os.path.basename(file_path)
        absorbance = opus_data['AB']
        
        # Z-score normalization:
        normalized_absorbance = z_score_normalization(absorbance)
        
        # Save the normalized spectrum
        save_path = os.path.join(output_directory, file_name.replace('.0', '_normalized.0'))
        np.savetxt(save_path, normalized_absorbance, delimiter=',', fmt='%f')
        print(f"Normalized data saved as: {save_path}")

root = tk.Tk()
root.withdraw()  # Hide the main window
file_paths = filedialog.askopenfilenames()

if file_paths:
    open_files_and_save_normalized(file_paths)
# Out:
# Normalized data saved as: normalized_spectra/20240304 OE 1_normalized.0000
# Normalized data saved as: normalized_spectra/20240304 OE 1_normalized.0001
# Normalized data saved as: normalized_spectra/20240304 OE 1_normalized.0002
# Normalized data saved as: normalized_spectra/20240304 OE 1_normalized.0003
# Normalized data saved as: normalized_spectra/20240304 OE 1_normalized.0004
# Normalized data saved as: normalized_spectra/20240304 OE 2_normalized.0000
# Normalized data saved as: normalized_spectra/20240304 OE 2_normalized.0001
# Normalized data saved as: normalized_spectra/20240304 OE 2_normalized.0002
# Normalized data saved as: normalized_spectra/20240304 OE 2_normalized.0003
# Normalized data saved as: normalized_spectra/20240304 OE 2_normalized.0004
# Normalized data saved as: normalized_spectra/20240304 OE 3_normalized.0000
# Normalized data saved as: normalized_spectra/20240304 OE 3_normalized.0001
# Normalized data saved as: normalized_spectra/20240304 OE 3_normalized.0002
# Normalized data saved as: normalized_spectra/20240304 OE 3_normalized.0003
# Normalized data saved as: normalized_spectra/20240304 OE 3_normalized.0004
# Normalized data saved as: normalized_spectra/20240304 OE 4_normalized.0000
# Normalized data saved as: normalized_spectra/20240304 OE 4_normalized.0001
# Normalized data saved as: normalized_spectra/20240304 OE 4_normalized.0002
# Normalized data saved as: normalized_spectra/20240304 OE 4_normalized.0003
# Normalized data saved as: normalized_spectra/20240304 OE 4_normalized.0004
# Normalized data saved as: normalized_spectra/20240304 OE 4_normalized.0005
# Normalized data saved as: normalized_spectra/20240304 OE 4_normalized.0006
# Normalized data saved as: normalized_spectra/20240304 OE 4_normalized.0007
# Normalized data saved as: normalized_spectra/20240304 OE 4_normalized.0008
# Normalized data saved as: normalized_spectra/20240304 OE 4_normalized.0009
# Normalized data saved as: normalized_spectra/20240304 OE 5_normalized.0000
# Normalized data saved as: normalized_spectra/20240304 OE 5_normalized.0001
# Normalized data saved as: normalized_spectra/20240304 OE 5_normalized.0002
# Normalized data saved as: normalized_spectra/20240304 OE 5_normalized.0003
# Normalized data saved as: normalized_spectra/20240304 OE 5_normalized.0004
# Normalized data saved as: normalized_spectra/20240304 OE 5_normalized.0005
# Normalized data saved as: normalized_spectra/20240304 OE 5_normalized.0006
# Normalized data saved as: normalized_spectra/20240304 OE 5_normalized.0007
# Normalized data saved as: normalized_spectra/20240304 OE 5_normalized.0008
# Normalized data saved as: normalized_spectra/20240304 OE 5_normalized.0009
# Normalized data saved as: normalized_spectra/20240304 RE 1_normalized.0000
# Normalized data saved as: normalized_spectra/20240304 RE 1_normalized.0001
# Normalized data saved as: normalized_spectra/20240304 RE 1_normalized.0002
# Normalized data saved as: normalized_spectra/20240304 RE 1_normalized.0003
# Normalized data saved as: normalized_spectra/20240304 RE 1_normalized.0004
# Normalized data saved as: normalized_spectra/20240304 RE 2_normalized.0000
# Normalized data saved as: normalized_spectra/20240304 RE 2_normalized.0001
# Normalized data saved as: normalized_spectra/20240304 RE 2_normalized.0002
# Normalized data saved as: normalized_spectra/20240304 RE 2_normalized.0003
# Normalized data saved as: normalized_spectra/20240304 RE 2_normalized.0004
# Normalized data saved as: normalized_spectra/20240304 RE 3_normalized.0000
# Normalized data saved as: normalized_spectra/20240304 RE 3_normalized.0001
# Normalized data saved as: normalized_spectra/20240304 RE 3_normalized.0002
# Normalized data saved as: normalized_spectra/20240304 RE 3_normalized.0003
# Normalized data saved as: normalized_spectra/20240304 RE 3_normalized.0004
# Normalized data saved as: normalized_spectra/20240304 RE 4_normalized.0000
# Normalized data saved as: normalized_spectra/20240304 RE 4_normalized.0001
# Normalized data saved as: normalized_spectra/20240304 RE 4_normalized.0002
# Normalized data saved as: normalized_spectra/20240304 RE 4_normalized.0003
# Normalized data saved as: normalized_spectra/20240304 RE 4_normalized.0004
# Normalized data saved as: normalized_spectra/20240304 RE 5_normalized.0000
# Normalized data saved as: normalized_spectra/20240304 RE 5_normalized.0001
# Normalized data saved as: normalized_spectra/20240304 RE 5_normalized.0002
# Normalized data saved as: normalized_spectra/20240304 RE 5_normalized.0003
# Normalized data saved as: normalized_spectra/20240304 RE 5_normalized.0004
# Normalized data saved as: normalized_spectra/20240304 TE 1_normalized.0000
# Normalized data saved as: normalized_spectra/20240304 TE 1_normalized.0001
# Normalized data saved as: normalized_spectra/20240304 TE 1_normalized.0002
# Normalized data saved as: normalized_spectra/20240304 TE 1_normalized.0003
# Normalized data saved as: normalized_spectra/20240304 TE 1_normalized.0004
# Normalized data saved as: normalized_spectra/20240304 TE 2_normalized.0000
# Normalized data saved as: normalized_spectra/20240304 TE 2_normalized.0001
# Normalized data saved as: normalized_spectra/20240304 TE 2_normalized.0002
# Normalized data saved as: normalized_spectra/20240304 TE 2_normalized.0003
# Normalized data saved as: normalized_spectra/20240304 TE 2_normalized.0004
# Normalized data saved as: normalized_spectra/20240304 TE 3_normalized.0000
# Normalized data saved as: normalized_spectra/20240304 TE 3_normalized.0001
# Normalized data saved as: normalized_spectra/20240304 TE 3_normalized.0002
# Normalized data saved as: normalized_spectra/20240304 TE 3_normalized.0003
# Normalized data saved as: normalized_spectra/20240304 TE 3_normalized.0004
# Normalized data saved as: normalized_spectra/20240304 TE 4_normalized.0000
# Normalized data saved as: normalized_spectra/20240304 TE 4_normalized.0001
# Normalized data saved as: normalized_spectra/20240304 TE 4_normalized.0002
# Normalized data saved as: normalized_spectra/20240304 TE 4_normalized.0003
# Normalized data saved as: normalized_spectra/20240304 TE 4_normalized.0004
# Normalized data saved as: normalized_spectra/20240304 TE 5_normalized.0000
# Normalized data saved as: normalized_spectra/20240304 TE 5_normalized.0001
# Normalized data saved as: normalized_spectra/20240304 TE 5_normalized.0002
# Normalized data saved as: normalized_spectra/20240304 TE 5_normalized.0003
# Normalized data saved as: normalized_spectra/20240304 TE 5_normalized.0004
